# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
df = pd.read_excel('/Users/zhanarorynbassar/Downloads/全国空气质量排行榜.xlsx')
#爬数据的方法为：在google sheet 使用 =IMPORTHTML("http://www.pm25.in/rank"; "table";1) 方程

# %%
data = df.copy()
data.head()
# Out:
#    排名    城市  AQI 空气质量\n指数类别 首要污染物  PM 2.5\n细颗粒物 PM 10\n可吸入颗粒物 CO\n一氧化碳  \
# 0   1  林芝地区   18          优   NaN             4            16     0.35
# 1   2    松原   21          优   NaN             3            20     0.35
# 2   3    白城   21          优   NaN             9            17     0.15
# 3   4  呼伦贝尔   21          优   NaN            13            15      0.2
# 4   5    绥化   21          优   NaN             9            15     0.25
#
#    NO2\n二氧化氮 O3\n臭氧1小时平均 O3_8h\n臭氧8小时平均  SO2\n二氧化硫
# 0          6          51             35          3
# 1          6          43             37          3
# 2          8          46             41          4
# 3          5          48             40          3
# 4         12          40             41          2

# %%
df.groupby(['空气质量\n指数类别'],as_index=False)['城市'].count()
# Out:
#   空气质量\n指数类别   城市
# 0          优  122
# 1          良  233
# 2       轻度污染   16
# 3       重度污染    1

# %%
df.groupby(['首要污染物'],as_index=False)['城市'].count()
# Out:
#                     首要污染物   城市
# 0                   臭氧1小时    2
# 1                   臭氧8小时   32
# 2       臭氧8小时 \n颗粒物(PM10)    4
# 3               颗粒物(PM10)  179
# 4              颗粒物(PM2.5)   36
# 5  颗粒物(PM2.5) \n颗粒物(PM10)    3

# %%
mpl.rcParams['font.sans-serif'] = ['Source Han Sans TW', 'sans-serif','DejaVu Sans']#为了避免系统读不出汉字报错

# %%
fig, ax = plt.subplots(figsize=(10,7))
data.groupby(['首要污染物']).count()['城市'].plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10,7))
data.groupby(['AQI']).count()['城市'].plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10,7))
data.groupby(['CO\n一氧化碳']).count()['城市'].plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10,7))
data.groupby(['NO2\n二氧化氮']).count()['城市'].plot(ax=ax)
